# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Thoma\Desktop\M2\Text Mining\Text_mining-Project-main\Tweet_Asterix.csv", sep = ";")

print(df["text"])
print(df.shape)

df.head()

def date_format(df):
    df["created_at"] = df["created_at"].str[:10]
    df=df.rename(columns={"created_at" : "Date"})
    return df

df1=date_format(df)
df1.head()
# Out:
# 0       Très bon retour spectateurs Allociné pour #ali...
# 1       J’vous jure c’est ni une aventure, ni une comé...
# 2       📚 Dans les librairies\nÀ découvrir dès aujourd...
# 3       @CarrefourFrance Bonjour, je participe pour te...
# 4       @CarrefourFrance #AsterixEtObelixLEmpireDuMili...
#                               ...
# 1382    ⭐️ÉTOILES DE LA SEMAINE⭐️\n\n#AsterixEtObelixL...
# 1383    La bande originale d' #AstérixEtObélixLEmpireD...
# 1384    @SarahRempe @ctmieuxavant33 @destinationcine @...
# 1385    #Asterixetobelixlempiredumilieu j'ai tenu 40 m...
# 1386    #AsterixEtObelixLEmpireDuMilieu\n#GuillaumeCan...
# Name: text, Length: 1387, dtype: object
# (1387, 6)
#    Unnamed: 0                                context_annotations        Date  \
# 0           0                                                NaN  2023-02-08
# 1           1                                                NaN  2023-02-08
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'context_annotations', 'created_at', 'edit_history_tweet_ids', 'id', 'text']

# %%
def function1(df):
    df["created_at"] = pd.to_datetime(df["created_at"])
    freq = df.groupby(df["created_at"].dt.date)["text"].count()
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(freq.index, freq.values, marker="o")
    ax.set_xlabel("Date")
    ax.set_ylabel("Fréquence des Tweets")
    ax.set_title("Fréquence des Tweets par jour")
    ax.grid(True)
    
    for x, y in zip(freq.index, freq.values):
        label = "{:.0f}".format(y)  
        ax.annotate(label, (x, y), textcoords="offset points", xytext=(0,10), ha='center')
    return plt

# %%
function1(df)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Thoma\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
df2 = pd.read_csv(r"C:\Users\Thoma\Desktop\M2\Text Mining\Text_mining-Project-main\Tweet_Asterix_0802.csv", sep = ";")
df2=date_format(df2)
df2.head(1385)
# Out:
#       Unnamed: 0                                context_annotations  \
# 0              0                                                NaN
# 1              1                                                NaN
# 2              2  [{'domain': {'id': '56', 'name': 'Actor', 'des...
# 3              3  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 4              4  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# ...          ...                                                ...
# 1380        1380  [{'domain': {'id': '56', 'name': 'Actor', 'des...
# 1381        1381                                                NaN
# 1382        1382  [{'domain': {'id': '46', 'name': 'Business Tax...
# 1383        1383  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1384        1384  [{'domain': {'id': '46', 'name': 'Business Tax...
#
#             Date edit_history_tweet_ids                   id  \
# 0     2023-02-08  [1623317443903987713]  1623317443903987713
# ...

# %%
df2.rename(columns={'Date': 'created_at'}, inplace=True)
df2.head()
df2.shape
# Out:
# (1386, 6)

# %%
def check_duplicate(df):
    return df.duplicated().any()
check_duplicate(df3)
# Out:
# False

# %%
print(df3.columns.tolist())
# Out:
# ['Unnamed: 0', 'context_annotations', 'Date', 'edit_history_tweet_ids', 'id', 'text', 'created_at']

# %%
df3=pd.concat([df1,df2])
print(df3.shape)

#df3.tail()

###.drop_duplicates()
###df3.shape
###df3["created_at"]=df3["Date"]
###df3.head()
###print(df3.columns.tolist())
###df3.drop(["Date","Unnamed: 0"],axis=1)
# Out:
# (2773, 6)
# (1387, 6)

# %%
pd.options.display.max_colwidth=200
df.iloc[178]
# Out:
# Unnamed: 0                                                                                                                                                                                                                    178
# context_annotations       [{'domain': {'id': '45', 'name': 'Brand Vertical', 'description': 'Top level entities that describe a Brands industry'}, 'entity': {'id': '781974596706635776', 'name': 'Retail industry'}}, {'domai...
# created_at                                                                                                                                                                                                             2023-02-06
# edit_history_tweet_ids                                                                                                                                                                                      [1622719329191034902]
# ...

# %%
index = df.loc[df['text'].str.contains('@CarrefourFrance')].index

# Supprimer les lignes avec les indices trouvés
df.drop(index, inplace=True)
df.shape
df.iloc[178]
# Out:
# Unnamed: 0                                                                                                                                                                                                                    260
# context_annotations       [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697439489880065', 'name': 'Tra...
# created_at                                                                                                                                                                                                             2023-02-06
# edit_history_tweet_ids                                                                                                                                                                                      [1622590777451847681]
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Thoma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import nest_asyncio  
nest_asyncio.apply()
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import seaborn as sns
# !pip install twint
#cleaning
import re
from nltk.tokenize import WordPunctTokenizer
from nltk.corpus import stopwords
# Sentiment Scoring
# !pip install textblob
#word cloud
# !pip install wordcloud
textes = ' '.join(df['text'])
from wordcloud import WordCloud


wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='magma', stopwords=None, max_words=200).generate(textes)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk

# Télécharger la liste de stop words en français
nltk.download('stopwords')

# Récupérer les textes de la colonne "text" du dataframe df
textes = df['text']

# Enlever les stop words
stop_words = set(stopwords.words('french'))
textes2 = [' '.join([mot for mot in texte.split() if mot.lower() not in stop_words]) for texte in textes]

# Ajouter la colonne "text2" au dataframe df
df['text2'] = textes2
df.head()

wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='magma', stopwords=None, max_words=200).generate(textes2)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Thoma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11676\1447497909.py in <module>
#      17 df.head()
#      18
# ---> 19 wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='magma', stopwords=None, max_words=200).generate(textes2)
#      20
#      21
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     637         self
#     638         """
# --> 639         return self.generate_from_text(text)
#     640
#     641     def _check_generated(self):
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     618         self
#     619         """
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk

# Télécharger la liste de stop words en français
nltk.download('stopwords')

# Récupérer les textes de la colonne "text2" du dataframe df
textes2 = df['text2'].tolist()

# Fusionner tous les textes en une seule chaîne
texte_concatene = ' '.join(textes2)

# Enlever les stop words
stop_words = set(stopwords.words('french'))
texte_sans_stop_words = ' '.join([mot for mot in texte_concatene.split() if mot.lower() not in stop_words])

# Créer l'objet WordCloud et le visualiser
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='magma', stopwords=None, max_words=200).generate(texte_sans_stop_words)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Thoma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
